# %%
import pandas as pd

df=pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df=df.drop(['Cabin','Ticket','Name'],axis=1)

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df=df.dropna()

# %%
import seaborn as sns
import matplotlib.pyplot as pt

demography=df['Sex'].value_counts()
pt.pie(demography,labels=demography.index, autopct='%1.1f%%')
pt.title("Demographic Insights")
# Out:
# Text(0.5, 1.0, 'Demographic Insights')

# %%
sns.violinplot(df['Age'])
pt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
sns.countplot(x='Sex', hue='Survived',data=df)
pt.title('Survival Count by Gender')
# Out:
# Text(0.5, 1.0, 'Survival Count by Gender')

# %%
sns.histplot(data=df, x='Age', hue='Survived',kde=True)
pt.title('Age Distribution of Passengers (Survived vs Not Survived)')
# Out:
# Text(0.5, 1.0, 'Age Distribution of Passengers (Survived vs Not Survived)')

# %%
sns.countplot(data=df,x='Embarked',hue='Survived')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.histplot(data=df, x='Fare', bins=30, kde=True, color='skyblue')
pt.title('Distribution of Ticket Prices')
pt.xlabel('Fare')
pt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
