# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
# Sample document
document = "A stemmer for English operating on the stem cat should identify such strings as cats jumps"

# Tokenization
tokens = nltk.word_tokenize(document)

# POS Tagging
pos_tags = nltk.pos_tag(tokens)

# Stop words removal
stop_words = set(stopwords.words('english'))
tokens = [token for token in tokens if token not in stop_words]

# Stemming
stemmer = PorterStemmer()
stemmed_tokens = [stemmer.stem(token) for token in tokens]

# Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in stemmed_tokens]

# Term Frequency and Inverse Document Frequency
vectorizer = TfidfVectorizer()
tf_idf_matrix = vectorizer.fit_transform([' '.join(lemmatized_tokens)])

print("Tokenized Document: ", tokens)
print("POS Tags: ", pos_tags)
print("Stemmed Tokens: ", stemmed_tokens)
print("Lemmatized Tokens: ", lemmatized_tokens)
print("TF-IDF Matrix: ", tf_idf_matrix.toarray())
# Out:
# Tokenized Document:  ['A', 'stemmer', 'English', 'operating', 'stem', 'cat', 'identify', 'strings', 'cats', 'jumps']
# POS Tags:  [('A', 'DT'), ('stemmer', 'NN'), ('for', 'IN'), ('English', 'NNP'), ('operating', 'VBG'), ('on', 'IN'), ('the', 'DT'), ('stem', 'NN'), ('cat', 'NN'), ('should', 'MD'), ('identify', 'VB'), ('such', 'JJ'), ('strings', 'NNS'), ('as', 'IN'), ('cats', 'NNS'), ('jumps', 'VBP')]
# Stemmed Tokens:  ['a', 'stemmer', 'english', 'oper', 'stem', 'cat', 'identifi', 'string', 'cat', 'jump']
# Lemmatized Tokens:  ['a', 'stemmer', 'english', 'oper', 'stem', 'cat', 'identifi', 'string', 'cat', 'jump']
# TF-IDF Matrix:  [[0.60302269 0.30151134 0.30151134 0.30151134 0.30151134 0.30151134
#   0.30151134 0.30151134]]
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Joining the lemmatized tokens into a single string
text = ' '.join(lemmatized_tokens)

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
