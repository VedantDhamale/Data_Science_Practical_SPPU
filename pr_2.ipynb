# %% [markdown]
# Create an “Academic performance” dataset of students and perform the following operations using
# Python.
#
# 1. Scan all variables for missing values and inconsistencies. If there are missing values and/or
# inconsistencies, use any of the suitable techniques to deal with them.
# 2. Scan all numeric variables for outliers. If there are outliers, use any of the suitable techniques
# to deal with them.
# 3. Apply data transformations on at least one of the variables. The purpose of this
# transformation should be one of the following reasons: to change the scale for better
# understanding of the variable, to convert a non-linear relation into a linear one, or to decrease
# the skewness and convert the distribution into a normal distribution.

# %%
import pandas as pd
import numpy as np

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,90,np.nan],"English_marks":[70,80,90,np.nan,60],"Science_marks":[80,90,np.nan,60,70],"History_marks":[90,np.nan,60,70,80],"Geography_marks":[np.nan,60,70,80,90]}

# %%
df1=pd.DataFrame(dict1)

# %%
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           90.0
# 1        2   Dipak         70.0           80.0           90.0            NaN
# 2        3  Shreya         80.0           90.0            NaN           60.0
# 3        4  Krisha         90.0            NaN           60.0           70.0
# 4        5   Pooja          NaN           60.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             60.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
df1.isnull().sum()
# Out:
# Roll_No            0
# Name               0
# Maths_marks        1
# English_marks      1
# Science_marks      1
# History_marks      1
# Geography_marks    1
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Roll_No          5 non-null      int64
#  1   Name             5 non-null      object
#  2   Maths_marks      4 non-null      float64
#  3   English_marks    4 non-null      float64
#  4   Science_marks    4 non-null      float64
#  5   History_marks    4 non-null      float64
#  6   Geography_marks  4 non-null      float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 412.0+ bytes

# %%
bool_series = pd.notnull(df1)
bool_series
# Out:
#    Roll_No  Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0     True  True         True           True           True           True
# 1     True  True         True           True           True          False
# 2     True  True         True           True          False           True
# 3     True  True         True          False           True           True
# 4     True  True        False           True           True           True
#
#    Geography_marks
# 0            False
# 1             True
# 2             True
# 3             True
# 4             True

# %%
# filling missing value using fillna() 
df1.fillna(0,inplace=True)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           90.0
# 1        2   Dipak         70.0           80.0           90.0            0.0
# 2        3  Shreya         80.0           90.0            0.0           60.0
# 3        4  Krisha         90.0            0.0           60.0           70.0
# 4        5   Pooja          0.0           60.0           70.0           80.0
#
#    Geography_marks
# 0              0.0
# 1             60.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           90.0
# 1        2   Dipak         70.0           80.0           90.0            NaN
# 2        3  Shreya         80.0           90.0            NaN           60.0
# 3        4  Krisha         90.0            NaN           60.0           70.0
# 4        5   Pooja          NaN           60.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             60.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# filling a missing value with
# previous ones 
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,60],"Science_marks":[80,91,np.nan,60,70],"History_marks":[76,np.nan,60,70,80],"Geography_marks":[np.nan,60,70,80,90]}
df1=pd.DataFrame(dict1)

# %%
df1.fillna(method ='pad')
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_26744\1848718746.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method ='pad')
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0           76.0
# 2        3  Shreya         80.0           40.0           91.0           60.0
# 3        4  Krisha         93.0           40.0           60.0           70.0
# 4        5   Pooja         93.0           60.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             60.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# filling a missing value with
# next ones
df1.fillna(method ='bfill')
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_26744\3214477383.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method ='bfill')
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0           68.0
# 2        3  Shreya         80.0           40.0           65.0           68.0
# 3        4  Krisha         93.0           50.0           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0             62.0
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# filling a null values using fillna()
df1["Maths_marks"].fillna(45, inplace = True)
df1["English_marks"].fillna(55, inplace = True)
df1["Science_marks"].fillna(65, inplace = True)
df1["History_marks"].fillna(75, inplace = True)
df1["Geography_marks"].fillna(85, inplace = True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_26744\2565814465.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["Maths_marks"].fillna(45, inplace = True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_26744\2565814465.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["English_marks"].fillna(55, inplace = True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_26744\2565814465.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["Science_marks"].fillna(65, inplace = True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_26744\2565814465.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["History_marks"].fillna(75, inplace = True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_26744\2565814465.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["Geography_marks"].fillna(85, inplace = True)

# %%
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0           75.0
# 2        3  Shreya         80.0           40.0           65.0           68.0
# 3        4  Krisha         93.0           55.0           65.0           70.0
# 4        5   Pooja         45.0           50.0           70.0           80.0
#
#    Geography_marks
# 0             85.0
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# filling a null values using fillna()
df1["Maths_marks"].fillna(int(df1["Maths_marks"].mean()), inplace=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_26744\1270300586.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["Maths_marks"].fillna(int(df1["Maths_marks"].mean()), inplace=True)

# %%
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja         75.0           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# will replace  Nan value in dataframe with value 85 
df1.replace(to_replace = np.nan, value = 85)
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0           85.0
# 2        3  Shreya         80.0           40.0           85.0           68.0
# 3        4  Krisha         93.0           85.0           65.0           70.0
# 4        5   Pooja         85.0           50.0           70.0           80.0
#
#    Geography_marks
# 0             85.0
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# to interpolate the missing values
df1.interpolate(method ='linear', limit_direction ='forward')
#c=(a+b)/2
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_26744\1794567949.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df1.interpolate(method ='linear', limit_direction ='forward')
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0           72.0
# 2        3  Shreya         80.0           40.0           78.0           68.0
# 3        4  Krisha         93.0           45.0           65.0           70.0
# 4        5   Pooja         93.0           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,75],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol           60           70.0           80.0           76.0
# 1        2   Dipak           70           80.0           91.0            NaN
# 2        3  Shreya           80           40.0            NaN           68.0
# 3        4  Krisha           93            NaN           65.0           70.0
# 4        5   Pooja           75           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# using dropna() function 
df1.dropna()
# Out:
#    Roll_No   Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 4        5  Pooja           75           50.0           70.0           80.0
#
#    Geography_marks
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# using dropna() function   
df1.dropna(how = 'all',inplace=True)

# %%
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# using dropna() function    
df1.dropna(axis = 1)
# Out:
#    Roll_No    Name
# 0        1    Amol
# 1        2   Dipak
# 2        3  Shreya
# 3        4  Krisha
# 4        5   Pooja

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[60,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0               60
# 1               62
# 2               70
# 3               80
# 4               90

# %%
# making new data frame with dropped NA values
df2 = df1.dropna(axis = 0, how ='any')

# %%
df2
# Out:
#    Roll_No  Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1  Amol         60.0           70.0           80.0           76.0
#
#    Geography_marks
# 0               60

# %% [markdown]
# # OUTLIERS

# %%
# Importing
import sklearn
# from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt
# import sklearn.datasets
 
df_boston =pd.read_csv('HousingData.csv')

df_boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %% [markdown]
# # 1. Visualization

# %%
# Box Plot
import seaborn as sns
sns.boxplot(df_boston['DIS'])
# Out:
# <Axes: >

# %%
# Position of the Outlier
print(np.where(df_boston['DIS']>10))
# Out:
# (array([351, 352, 353, 354, 355], dtype=int64),)

# %%
df_boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %% [markdown]
# # Using ScatterPlot

# %%
# Scatter plot
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df_boston['INDUS'], df_boston['TAX'])
 
# x-axis label
ax.set_xlabel('(Proportion non-retail business acres)/(town)')
 
# y-axis label
ax.set_ylabel('(Full-value property-tax rate)/( $10,000)')
plt.show()

# %%
# Position of the Outlier
print(np.where((df_boston['INDUS']>20) & (df_boston['TAX']>600)))
# Out:
# (array([488, 489, 490, 491, 492], dtype=int64),)

# %% [markdown]
# # 2. Z-score

# %%
# Z score
from scipy import stats
import numpy as np
 
z = np.abs(stats.zscore(df_boston['DIS']))
print(z)
# Out:
# 0      0.140214
# 1      0.557160
# 2      0.557160
# 3      1.077737
# 4      1.077737
#          ...
# 501    0.625796
# 502    0.716639
# 503    0.773684
# 504    0.668437
# 505    0.613246
# Name: DIS, Length: 506, dtype: float64

# %%
threshold = 3
 
# Position of the outlier
print(np.where(z > 3))
outlier_positions = (z > threshold) | (z < -threshold)
filtered = df_boston[~outlier_positions]
# Out:
# (array([351, 352, 353, 354, 355], dtype=int64),)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_26744\3132670124.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered = df_boston[~outlier_positions]

# %%
filtered.shape
# Out:
# (501, 14)

# %% [markdown]
# # 3. IQR (Inter Quartile Range)

# %% [markdown]
# # Removing the outliers

# %%
# Importing
# import sklearn
# from sklearn.datasets import load_boston
import pandas as pd

# Load the dataset
df_boston = pd.read_csv('HousingData.csv')

# # Create the dataframe
# column_name = bos_hou.feature_names
# df_boston = pd.DataFrame(bos_hou.data)
# df_boston.columns = column_name
df_boston.head()

''' Detection '''
# IQR
Q1 = np.percentile(df_boston['DIS'], 25,
				interpolation = 'midpoint')

Q3 = np.percentile(df_boston['DIS'], 75,
				interpolation = 'midpoint')
IQR = Q3 - Q1

print("Old Shape: ", df_boston.shape)

# Upper bound
upper = np.where(df_boston['DIS'] >= (Q3+1.5*IQR))
print(upper)
# Lower bound
lower = np.where(df_boston['DIS'] <= (Q1-1.5*IQR))
print(lower)

''' Removing the Outliers '''
df_boston.drop(upper[0], inplace = True)
df_boston.drop(lower[0], inplace = True)

print("New Shape: ", df_boston.shape)
# Out:
# Old Shape:  (506, 14)
# (array([351, 352, 353, 354, 355], dtype=int64),)
# (array([], dtype=int64),)
# New Shape:  (501, 14)

# %% [markdown]
# # data transformations

# %% [markdown]
# # Method 1: Using Pandas and Numpy

# %%
import seaborn as sns
import pandas as pd
import numpy as np

data = sns.load_dataset('iris')
print('Original Dataset')
data.head()
# Out:
# Original Dataset
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Min-Max Normalization
df = data.drop('species', axis=1)
df_norm = (df - df.min()) / (df.max() - df.min())
# df_norm = pd.concat([df_norm, data['species']], axis=1)

print("Scaled Dataset Using Pandas")
df_norm.head()
# Out:
# Scaled Dataset Using Pandas
#    sepal_length  sepal_width  petal_length  petal_width
# 0      0.222222     0.625000      0.067797     0.041667
# 1      0.166667     0.416667      0.067797     0.041667
# 2      0.111111     0.500000      0.050847     0.041667
# 3      0.083333     0.458333      0.084746     0.041667
# 4      0.194444     0.666667      0.067797     0.041667

# %%
# skewness along the index axis

df.skew(axis = 0, skipna = True)
# Out:
# sepal_length    0.314911
# sepal_width     0.318966
# petal_length   -0.274884
# petal_width    -0.102967
# dtype: float64

# %%
# find skewness in each row
df.skew(axis = 1, skipna = True)
# Out:
# 0      0.189328
# 1      0.404389
# 2      0.208782
# 3      0.120130
# 4      0.090753
#          ...
# 145    0.351514
# 146    0.256478
# 147    0.134795
# 148   -0.146244
# 149   -0.185387
# Length: 150, dtype: float64

# %% [markdown]
# For a unimodal distribution, negative skew commonly indicates that the tail is on the left side of the distribution, and positive skew indicates that the tail is on the right. In cases where one tail is long but the other tail is fat, skewness does not obey a simple rule. For example, a zero value means that the tails on both sides of the mean balance out overall; this is the case for a symmetric distribution, but can also be true for an asymmetric distribution where one tail is long and thin, and the other is short but fat.

# %% [markdown]
# # Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics

# Calculating mean and standard deviation
mean = statistics.mean(df_norm["sepal_length"])
sd = statistics.stdev(df_norm["sepal_length"])
  
plt.plot(df_norm["sepal_length"], norm.pdf(df_norm["sepal_length"], mean, sd))
plt.show()
print(mean)
print(sd)
# Out:
# 0.4287037037037037
# 0.2300183688827397

# %% [markdown]
# # Standardization

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import seaborn as sns

data = sns.load_dataset('iris')
print('Original Dataset')
data.head()
# Out:
# Original Dataset
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.drop(["species"],inplace=True,axis=1)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
std_scaler = StandardScaler()

df_scaled = std_scaler.fit_transform(data.to_numpy())
df_scaled = pd.DataFrame(df_scaled, columns=[
'sepal_length','sepal_width','petal_length','petal_width'])

print("Scaled Dataset Using StandardScaler")
df_scaled.head()
# Out:
# Scaled Dataset Using StandardScaler
#    sepal_length  sepal_width  petal_length  petal_width
# 0     -0.900681     1.019004     -1.340227    -1.315444
# 1     -1.143017    -0.131979     -1.340227    -1.315444
# 2     -1.385353     0.328414     -1.397064    -1.315444
# 3     -1.506521     0.098217     -1.283389    -1.315444
# 4     -1.021849     1.249201     -1.340227    -1.315444
